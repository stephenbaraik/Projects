# %%
import pandas as pd

# %%
data = [
    {"Company": "Quantiphi Analytics Solutions Pvt. Ltd.", "Email": "info@quantiphi.com", "Category": "AI & Data Analytics", "Source": "https://quantiphi.com"},
    {"Company": "Data Science Wizards Pvt. Ltd.", "Email": "contact@datasciencewizards.ai", "Category": "Data Science Consulting", "Source": "https://datasciencewizards.ai"},
    {"Company": "Credence Analytics (I) Pvt. Ltd.", "Email": "anitakumar@credenceanalytics.com", "Category": "Financial Analytics", "Source": "https://www.credenceanalytics.com"},
    {"Company": "Decimal Point Analytics", "Email": "info@decimalpointanalytics.com", "Category": "AI Data Analytics & Market Research", "Source": "https://decimalpointanalytics.com"},
    {"Company": "Persistent Systems", "Email": "investors@persistent.com", "Category": "IT & Data Engineering", "Source": "https://www.persistent.com"},
    {"Company": "Indus Net Technologies (INT)", "Email": "info@intglobal.com", "Category": "IT & Data Solutions", "Source": "https://www.indusnet.co.in"},
    {"Company": "Polestar Solutions & Services", "Email": "contactus@polestarllp.com", "Category": "Business Intelligence / Data Science", "Source": "https://www.polestarllp.com"},
    {"Company": "Fractal Analytics", "Email": "investorrelations@fractal.ai", "Category": "AI & Analytics", "Source": "https://www.fractal.ai"},
    {"Company": "Cartesian Consulting", "Email": "info@cartesianconsulting.com", "Category": "Marketing Analytics", "Source": "https://www.cartesianconsulting.com"},
    {"Company": "Bloomberg India", "Email": None, "Category": "Finance / Data Analytics", "Source": "https://www.bloomberg.com"},
    {"Company": "Deloitte India", "Email": None, "Category": "Consulting / Data Analytics", "Source": "https://www.deloitte.com/in"},
    {"Company": "Accenture India", "Email": None, "Category": "IT / Analytics Consulting", "Source": "https://www.accenture.com/in"},
    {"Company": "Tata Consultancy Services (TCS)", "Email": "corporate.office@tcs.com", "Category": "IT / Data Science Services", "Source": "https://www.tcs.com"},
    {"Company": "Wipro", "Email": None, "Category": "IT / Data Science Services", "Source": "https://www.wipro.com"},
    {"Company": "M76 Analytics", "Email": "info@m76analytics.com", "Category": "Big Data / Startup", "Source": "https://www.m76analytics.com"},
    {"Company": "Feature Ventures", "Email": None, "Category": "Big Data / Startup", "Source": "https://wellfound.com/startups/feature-ventures"},
    {"Company": "Insight Fusion Analytics", "Email": "inquiries@insightfusionanalytics.com", "Category": "Analytics / AI", "Source": "https://www.insightfusionanalytics.com"},
    {"Company": "Arohanam Tech", "Email": "info@arohanamtechllp.com", "Category": "Tech / Analytics Startup", "Source": "https://www.arohanamtechllp.com"},
    {"Company": "Rushkar Technology Pvt. Ltd.", "Email": "sales@rushkar.com", "Category": "IT / BI Consulting", "Source": "https://www.rushkar.com"},
    {"Company": "Navsoft", "Email": "info@navsoft.in", "Category": "Software / Analytics", "Source": "https://www.navsoft.in"},
    {"Company": "Cymetrix Software", "Email": "info@cymetrixsoft.com", "Category": "IT / Analytics Consulting", "Source": "https://www.cymetrixsoft.com"},
     {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Data Analytics", 
     "Source": "https://fractal.ai"},

    {"Company": "Tredence", 
     "Email": "info@tredence.com", 
     "Category": "AI and Data Science Consulting", 
     "Source": "https://www.tredence.com"},

    {"Company": "Exponentia AI", 
     "Email": "info@exponentia.ai", 
     "Category": "AI & Machine Learning Solutions", 
     "Source": "https://www.exponentia.ai"},

    {"Company": "Mu Sigma", 
     "Email": "contact@mu-sigma.com", 
     "Category": "Decision Sciences / Data Analytics", 
     "Source": "https://www.mu-sigma.com"},

    {"Company": "Mactores", 
     "Email": "info@mactores.com", 
     "Category": "Data Engineering / Cloud Analytics", 
     "Source": "https://www.mactores.com"},

    {"Company": "Data Science Wizards", 
     "Email": "contact@datasciencewizards.ai", 
     "Category": "AI Platform / Data Science Solutions", 
     "Source": "https://www.datasciencewizards.ai"},

    {"Company": "Kraft Heinz (Analytics Division, Mumbai)", 
     "Email": "india@kraftheinz.com", 
     "Category": "FMCG / Analytics", 
     "Source": "https://builtinmumbai.in"},

    {"Company": "MiQ Digital", 
     "Email": "info@wearemiq.com", 
     "Category": "Marketing Analytics / AdTech", 
     "Source": "https://www.wearemiq.com"},

    {"Company": "MicroStrategy India", 
     "Email": "info@microstrategy.com", 
     "Category": "Business Intelligence / Data Analytics", 
     "Source": "https://www.microstrategy.com"},

    {"Company": "NICE CXone (NICE Ltd.)", 
     "Email": "info@nice.com", 
     "Category": "CX Analytics / AI Automation", 
     "Source": "https://www.nice.com"},

    {"Company": "Assesshub", 
     "Email": "info@assesshub.com", 
     "Category": "HR Analytics / Talent Assessment", 
     "Source": "https://www.assesshub.com"},

    {"Company": "Hansa Cequity", 
     "Email": "info@hansacequity.com", 
     "Category": "Marketing Analytics / CRM", 
     "Source": "https://www.hansacequity.com"},

    {"Company": "Truckola", 
     "Email": "info@truckola.in", 
     "Category": "Logistics Data Platform", 
     "Source": "https://www.truckola.in"},

    {"Company": "WebEngage", 
     "Email": "sales@webengage.com", 
     "Category": "Customer Data Platform / Marketing Automation", 
     "Source": "https://www.webengage.com"},

    {"Company": "Medront", 
     "Email": "info@medront.com", 
     "Category": "Healthcare Data Analytics", 
     "Source": "https://www.f6s.com/startup/medront"},

    {"Company": "vPhrase Analytics", 
     "Email": "info@vphrase.com", 
     "Category": "Narrative Data Reporting / AI Analytics", 
     "Source": "https://www.vphrase.com"},

    {"Company": "TheLightbulb.AI", 
     "Email": "contact@thelightbulb.ai", 
     "Category": "Emotion AI / Computer Vision Analytics", 
     "Source": "https://www.thelightbulb.ai"},

    {"Company": "InCred Financial", 
     "Email": "customercare@incred.com", 
     "Category": "FinTech / Data Analytics", 
     "Source": "https://www.incred.com"},

    {"Company": "Boston Consulting Group (BCG X)", 
     "Email": "bcgx@bcg.com", 
     "Category": "AI & Strategy Consulting", 
     "Source": "https://www.bcg.com/bcgx"},
    {"Company": "ScatterPie Analytics", 
     "Email": "info@scatterpie.io", 
     "Category": "Data Analytics Consulting / BI Solutions", 
     "Source": "https://www.scatterpie.io"},

    {"Company": "Straive", 
     "Email": "contact@straive.com", 
     "Category": "Data Analytics & AI Operationalization / Knowledge Services", 
     "Source": "https://www.straive.com"},

    {"Company": "Accenture India (AI & Data Science Careers)", 
     "Email": None, 
     "Category": "Global IT / AI Consulting", 
     "Source": "https://www.accenture.com/ai-data-science-careers"},

    {"Company": "Cartesian Consulting", 
     "Email": "info@cartesianconsulting.com", 
     "Category": "Marketing Analytics / Data Science", 
     "Source": "https://www.cartesianconsulting.com"},

    {"Company": "Quantiphi Analytics Solutions Pvt. Ltd.", 
     "Email": "info@quantiphi.com", 
     "Category": "AI-First Digital Engineering / Data Analytics", 
     "Source": "https://www.quantiphi.com"},

    {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Advanced Analytics", 
     "Source": "https://www.fractal.ai"},

    {"Company": "Brillio", 
     "Email": "info@brillio.com", 
     "Category": "Digital Transformation / Big Data", 
     "Source": "https://www.brillio.com"},

    {"Company": "Keen Solution", 
     "Email": "info@keensolution.com", 
     "Category": "Big Data Development / Cloud Analytics", 
     "Source": "https://www.goodfirms.co/big-data-analytics"},

    {"Company": "Decimal Point Analytics", 
     "Email": "info@decimalpointanalytics.com", 
     "Category": "AI Data Analytics & Market Research", 
     "Source": "https://www.decimalpointanalytics.com"},

    {"Company": "Oneture Technologies Pvt. Ltd.", 
     "Email": "info@oneture.com", 
     "Category": "Cloud Data Engineering / AI", 
     "Source": "https://www.oneture.com"},

    {"Company": "Axtria", 
     "Email": "marketing@axtria.com", 
     "Category": "AI-Driven Life Sciences Data & Analytics", 
     "Source": "https://www.axtria.com"},

    {"Company": "DataToBiz", 
     "Email": "hello@datatobiz.com", 
     "Category": "Data Science, AI & BI Consulting", 
     "Source": "https://www.datatobiz.com"},

    {"Company": "SG Analytics", 
     "Email": "info@sganalytics.com", 
     "Category": "Research, Data Insights & Analytics", 
     "Source": "https://www.sganalytics.com"},

    {"Company": "IMS Proschool (Analytics Training)", 
     "Email": "info@proschoolonline.com", 
     "Category": "Education / Data Analytics Training", 
     "Source": "https://proschoolonline.com/blog"},
    {"Company": "Accenture", 
     "Email": None, 
     "Category": "AI & Data Science Consulting / IT Services", 
     "Source": "https://www.accenture.com/in-en/careers/ai-data-science"},

    {"Company": "Capgemini India", 
     "Email": "contact.in@capgemini.com", 
     "Category": "IT & Analytics Consulting", 
     "Source": "https://www.capgemini.com/in-en"},

    {"Company": "Cognizant", 
     "Email": "info@cognizant.com", 
     "Category": "IT Services / Data Science", 
     "Source": "https://www.cognizant.com"},

    {"Company": "ZS Associates", 
     "Email": "info.india@zs.com", 
     "Category": "Analytics & Consulting", 
     "Source": "https://www.zs.com"},

    {"Company": "J.P. Morgan", 
     "Email": None, 
     "Category": "Financial Services / Data Science", 
     "Source": "https://www.jpmorgan.com"},

    {"Company": "C5i (Human | AI | Impact)", 
     "Email": "contact@c5i.ai", 
     "Category": "AI & Analytics Provider", 
     "Source": "https://www.c5i.ai"},

    {"Company": "Oracle India", 
     "Email": "inpress_ww@oracle.com", 
     "Category": "Cloud / Data Science Software", 
     "Source": "https://www.oracle.com/in"},

    {"Company": "Quantiphi", 
     "Email": "info@quantiphi.com", 
     "Category": "AI-First Digital Engineering", 
     "Source": "https://www.quantiphi.com"},

    {"Company": "MathCo (The Math Company)", 
     "Email": "contact@themathcompany.com", 
     "Category": "AI & Data Science Consulting", 
     "Source": "https://www.themathcompany.com"},

    {"Company": "IBM India", 
     "Email": "inquiries@in.ibm.com", 
     "Category": "Data Science & Enterprise AI", 
     "Source": "https://www.ibm.com/in-en"},

    {"Company": "Cloudera", 
     "Email": "info@cloudera.com", 
     "Category": "Big Data Platform / Cloud Analytics", 
     "Source": "https://www.cloudera.com"},

    {"Company": "LatentView Analytics", 
     "Email": "info@latentview.com", 
     "Category": "Data Analytics / AI Solutions", 
     "Source": "https://www.latentview.com"},

    {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Decision Intelligence", 
     "Source": "https://www.fractal.ai"},

    {"Company": "TransUnion CIBIL", 
     "Email": "consumer.support@cibil.com", 
     "Category": "Credit Risk / Data Analytics", 
     "Source": "https://www.transunioncibil.com"},

    {"Company": "Datamatics Global Services Ltd.", 
     "Email": "marketing@datamatics.com", 
     "Category": "Digital Tech, AI & Data Analytics", 
     "Source": "https://www.datamatics.com"},

    {"Company": "AlphaSense", 
     "Email": "info@alpha-sense.com", 
     "Category": "Market Intelligence / AI Research", 
     "Source": "https://www.alpha-sense.com"},

    {"Company": "Datadog", 
     "Email": "contact@datadoghq.com", 
     "Category": "Cloud Monitoring / Data Observability", 
     "Source": "https://www.datadoghq.com"},

    {"Company": "Krafting Networks", 
     "Email": "info@kraftingnetworks.com", 
     "Category": "Data / Cloud Solutions Startup", 
     "Source": "https://www.wellfound.com/startups/mumbai/analytics"},

    {"Company": "Drona Pay", 
     "Email": "contact@dronapay.com", 
     "Category": "FinTech / Data-Driven Fraud Detection", 
     "Source": "https://www.dronapay.com"},

    {"Company": "Cityscope", 
     "Email": "info@cityscope.media", 
     "Category": "Urban Data / Mobility Analytics", 
     "Source": "https://www.cityscope.media"},

    {"Company": "Teamie", 
     "Email": "hello@theteamie.com", 
     "Category": "EdTech / Learning Analytics", 
     "Source": "https://www.theteamie.com"},

    {"Company": "Fornax", 
     "Email": "contact@fornaxanalytics.com", 
     "Category": "Data Analytics Startup", 
     "Source": "https://www.wellfound.com/startups/mumbai/analytics"},

    {"Company": "Pettle", 
     "Email": "info@pettle.in", 
     "Category": "Health / Data Analytics Startup", 
     "Source": "https://www.pettle.in"},

    {"Company": "Navsoft", 
     "Email": "info@navsoft.in", 
     "Category": "Software / BI & Analytics", 
     "Source": "https://www.navsoft.in"},

    {"Company": "Exponentia.ai", 
     "Email": "info@exponentia.ai", 
     "Category": "AI Transformation / Data Analytics", 
     "Source": "https://www.exponentia.ai"},

    {"Company": "Indus Net Technologies Pvt. Ltd.", 
     "Email": "info@intglobal.com", 
     "Category": "IT / Analytics Consulting", 
     "Source": "https://www.indusnet.co.in"},

    {"Company": "Cymetrix Software", 
     "Email": "info@cymetrixsoft.com", 
     "Category": "CRM / Analytics Consulting", 
     "Source": "https://www.cymetrixsoft.com"},

    {"Company": "Kockpit Analytics", 
     "Email": "info@kockpit.in", 
     "Category": "Business Intelligence / Power BI Solutions", 
     "Source": "https://www.kockpit.in"},

    {"Company": "Infocepts", 
     "Email": "contact@infocepts.com", 
     "Category": "Data Analytics & AI Consulting", 
     "Source": "https://www.infocepts.ai"},

    {"Company": "Tiger Analytics", 
     "Email": "info@tigeranalytics.com", 
     "Category": "AI Cloud / Advanced Analytics", 
     "Source": "https://www.tigeranalytics.com"},

    {"Company": "SAS India", 
     "Email": "info@sas.com", 
     "Category": "Analytics Software / Data Management", 
     "Source": "https://www.sas.com/en_in"},

    {"Company": "Persistent Systems", 
     "Email": "investors@persistent.com", 
     "Category": "IT / Data Engineering", 
     "Source": "https://www.persistent.com"},

    {"Company": "LogiNext Solutions", 
     "Email": "info@loginextsolutions.com", 
     "Category": "Logistics AI / Data Science", 
     "Source": "https://www.loginextsolutions.com"},

    {"Company": "Gupshup", 
     "Email": "contact@gupshup.io", 
     "Category": "Conversational AI / Messaging Analytics", 
     "Source": "https://www.gupshup.io"},

    {"Company": "Haptik", 
     "Email": "hello@haptik.ai", 
     "Category": "Conversational AI / Chatbot Analytics", 
     "Source": "https://www.haptik.ai"},

    {"Company": "Softlabs Group", 
     "Email": "info@softlabsgroup.com", 
     "Category": "Software / AI & Data Solutions", 
     "Source": "https://www.softlabsgroup.com"},
    {"Company": "J.P. Morgan Chase & Co.", 
     "Email": None, 
     "Category": "Financial Services / AI & Data Analytics Internships", 
     "Source": "https://www.jpmorganchase.com/careers/programs"},

    {"Company": "Apexon", 
     "Email": "contact@apexon.com", 
     "Category": "Digital Engineering / Data & AI Solutions", 
     "Source": "https://www.apexon.com"},

    {"Company": "LatentView Analytics", 
     "Email": "info@latentview.com", 
     "Category": "AI & Data Analytics Consulting", 
     "Source": "https://www.latentview.com"},

    {"Company": "CRE Matrix", 
     "Email": "info@crematrix.com", 
     "Category": "Real Estate Data Analytics / Market Intelligence", 
     "Source": "https://www.crematrix.com"},

    {"Company": "QuickXpert Infotech", 
     "Email": "info@quickxpertinfotech.com", 
     "Category": "Data Analytics & IT Training Institute", 
     "Source": "https://www.quickxpertinfotech.com"},

    {"Company": "Techdata Solutions", 
     "Email": "info@techdatasolution.co.in", 
     "Category": "Analytics & AI Training / Education", 
     "Source": "https://www.techdatasolution.co.in"},

    {"Company": "Procter & Gamble (P&G India)", 
     "Email": None, 
     "Category": "FMCG / Data Science & Consumer Insights", 
     "Source": "https://www.pgcareers.com"},

    {"Company": "Skitch Technologies Pvt. Ltd.", 
     "Email": "contact@skitchtech.com", 
     "Category": "AI & Data Science / Tech Startup", 
     "Source": "https://www.simplyhired.co.in/search?l=mumbai,+maharashtra"},

    {"Company": "Hirezy.ai", 
     "Email": "info@hirezy.ai", 
     "Category": "AI Recruitment / HR Data Analytics", 
     "Source": "https://www.hirezy.ai"},

    {"Company": "NTT DATA", 
     "Email": "info@nttdata.com", 
     "Category": "IT & SAP Business Analytics Solutions", 
     "Source": "https://www.nttdata.com/global"},
    {"Company": "IQVIA", 
     "Email": "info@iqvia.com", 
     "Category": "Healthcare Data Analytics / Connected Intelligence", 
     "Source": "https://www.iqvia.com"},

    {"Company": "Teradata", 
     "Email": "info@teradata.com", 
     "Category": "Cloud Data Platform / Trusted AI", 
     "Source": "https://www.teradata.com"},

    {"Company": "LatentView Analytics", 
     "Email": "info@latentview.com", 
     "Category": "AI & Advanced Analytics Consulting", 
     "Source": "https://www.latentview.com"},

    {"Company": "Polestar Solutions & Services", 
     "Email": "contactus@polestarllp.com", 
     "Category": "Business Intelligence / Data Analytics", 
     "Source": "https://www.polestarllp.com"},

    {"Company": "Developer’s Dev", 
     "Email": "info@developers.dev", 
     "Category": "Software & Data Analytics Services", 
     "Source": "https://housing.com/home/commercial-realty"},

    {"Company": "Indus Net Technologies Pvt. Ltd.", 
     "Email": "info@intglobal.com", 
     "Category": "IT / Data Solutions", 
     "Source": "https://www.indusnet.co.in"},

    {"Company": "Blackburn Labs", 
     "Email": "contact@blackburnlabs.com", 
     "Category": "Data Engineering / Software Development", 
     "Source": "https://www.blackburnlabs.com"},

    {"Company": "Exponentia.ai", 
     "Email": "info@exponentia.ai", 
     "Category": "AI & Data Science Transformation", 
     "Source": "https://www.exponentia.ai"},

    {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Decision Intelligence", 
     "Source": "https://www.fractal.ai"},

    {"Company": "Datagrid Solutions", 
     "Email": "info@datagrid.co.in", 
     "Category": "Software Development / IT Outsourcing", 
     "Source": "https://datagrid.co.in"},

    {"Company": "Procter & Gamble (P&G India)", 
     "Email": None, 
     "Category": "FMCG / Consumer Data Analytics", 
     "Source": "https://www.pgcareers.com"},

    {"Company": "UBS India", 
     "Email": None, 
     "Category": "Financial Services / Data Science", 
     "Source": "https://www.ubs.com"},

    {"Company": "hirezy.ai", 
     "Email": "info@hirezy.ai", 
     "Category": "HR Tech / AI-Driven Recruitment Analytics", 
     "Source": "https://www.hirezy.ai"},

    {"Company": "IndiaMART Big Data Services", 
     "Email": "support@indiamart.com", 
     "Category": "Marketplace / Big Data Services", 
     "Source": "https://dir.indiamart.com"},

    {"Company": "Rise Institute", 
     "Email": "info@riseinstitute.tech", 
     "Category": "Education / Data Science Training", 
     "Source": "https://riseinstitute.tech"},
    {"Company": "DeveLearn", 
     "Email": "info@develearn.in", 
     "Category": "IT Training / Data Science & Analytics Institute", 
     "Source": "https://www.develearn.in"},

    {"Company": "Polestar Solutions & Services", 
     "Email": "contactus@polestarllp.com", 
     "Category": "Business Intelligence / Data Analytics", 
     "Source": "https://www.polestarllp.com"},

    {"Company": "Developer’s Dev", 
     "Email": "info@developers.dev", 
     "Category": "Software & Data Analytics Development", 
     "Source": "https://housing.com/home/commercial-realty"},

    {"Company": "Indus Net Technologies Pvt. Ltd.", 
     "Email": "info@intglobal.com", 
     "Category": "IT / Analytics Consulting", 
     "Source": "https://www.indusnet.co.in"},

    {"Company": "Blackburn Labs", 
     "Email": "contact@blackburnlabs.com", 
     "Category": "Data Engineering / Custom Software", 
     "Source": "https://www.blackburnlabs.com"},

    {"Company": "Exponentia.ai", 
     "Email": "info@exponentia.ai", 
     "Category": "AI Transformation / Data Analytics", 
     "Source": "https://www.exponentia.ai"},

    {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Decision Intelligence", 
     "Source": "https://www.fractal.ai"},

    {"Company": "Procter & Gamble (P&G India)", 
     "Email": None, 
     "Category": "FMCG / Data Science for Consumer Insights", 
     "Source": "https://www.pgcareers.com"},

    {"Company": "Skitch Technologies Pvt. Ltd.", 
     "Email": "contact@skitchtech.com", 
     "Category": "AI / ML & Data Science Services", 
     "Source": "https://www.simplyhired.co.in/search?l=mumbai,+maharashtra"},

    {"Company": "UBS India", 
     "Email": None, 
     "Category": "Financial Services / Data Science", 
     "Source": "https://www.ubs.com"},

    {"Company": "hirezy.ai", 
     "Email": "info@hirezy.ai", 
     "Category": "AI Recruitment / Data Analytics", 
     "Source": "https://www.hirezy.ai"},

    {"Company": "Itvedant", 
     "Email": "info@itvedant.com", 
     "Category": "Education / Data Science & AI Training", 
     "Source": "https://www.itvedant.com/data-science-and-ai"},

    {"Company": "UnitedHealth Group (Optum)", 
     "Email": "careers@optum.com", 
     "Category": "Healthcare / Applied AI & Data Analytics", 
     "Source": "https://careers.unitedhealthgroup.com"},

    {"Company": "Xoriant", 
     "Email": "info@xoriant.com", 
     "Category": "Digital Engineering / Data & Analytics Modernization", 
     "Source": "https://www.xoriant.com"},

    {"Company": "Chistats.ai", 
     "Email": "info@chistats.ai", 
     "Category": "AI Solutions / Data Engineering & Analytics", 
     "Source": "https://www.chistats.ai"},

    {"Company": "Hexaware Technologies", 
     "Email": "marketing@hexaware.com", 
     "Category": "IT Consulting / Cloud & Data Solutions", 
     "Source": "https://www.hexaware.com"},

    {"Company": "IBM India", 
     "Email": "inquiries@in.ibm.com", 
     "Category": "Technology / AI & Cloud Data Solutions", 
     "Source": "https://www.ibm.com/in-en"},

    {"Company": "eClerx", 
     "Email": "info@eclerx.com", 
     "Category": "Data Analytics / Process Management Services", 
     "Source": "https://careers.eclerx.com"},
    {"Company": "CleverX", 
     "Email": "info@cleverx.com", 
     "Category": "Expert Network / Data Science Consulting Marketplace", 
     "Source": "https://cleverx.com/hire/mumbai"},

    {"Company": "Unilever India", 
     "Email": None, 
     "Category": "FMCG / Data & Analytics", 
     "Source": "https://www.unilever.com"},

    {"Company": "Spotify India", 
     "Email": None, 
     "Category": "Media / Data Science & Recommendation Systems", 
     "Source": "https://www.spotify.com"},

    {"Company": "VISA Inc.", 
     "Email": "indiaqueries@visa.com", 
     "Category": "FinTech / Data Analytics", 
     "Source": "https://www.visa.com"},

    {"Company": "Michael Page India", 
     "Email": "mumbai@michaelpage.co.in", 
     "Category": "Recruitment / Analytics Hiring", 
     "Source": "https://www.michaelpage.co.in"},

    {"Company": "Deutsche Bank India", 
     "Email": None, 
     "Category": "Banking / Risk Analytics & Data Science", 
     "Source": "https://www.db.com"},

    {"Company": "Colgate-Palmolive India", 
     "Email": "consumeraffairs_india@colpal.com", 
     "Category": "FMCG / Consumer Analytics", 
     "Source": "https://www.colgatepalmolive.co.in"},

    {"Company": "London Stock Exchange Group (LSEG)", 
     "Email": "info@lseg.com", 
     "Category": "Financial Data & Analytics", 
     "Source": "https://www.lseg.com"},

    {"Company": "UBS India", 
     "Email": None, 
     "Category": "Banking / AI & Data Science", 
     "Source": "https://www.ubs.com"},

    {"Company": "Mphasis", 
     "Email": "info@mphasis.com", 
     "Category": "AI-Led Digital Transformation / Data Services", 
     "Source": "https://www.mphasis.com"},

    {"Company": "TCG Digital", 
     "Email": "contact@tcgdigital.com", 
     "Category": "Data Science & IT Consulting / AI Solutions", 
     "Source": "https://www.tcgdigital.com"},

    {"Company": "Techknomatic", 
     "Email": "info@techknomatic.com", 
     "Category": "Data Visualization & Analytics Services", 
     "Source": "https://www.techknomatic.com"},

    {"Company": "Sigmoid", 
     "Email": "contact@sigmoid.com", 
     "Category": "Data Engineering / Cloud AI Solutions", 
     "Source": "https://www.sigmoid.com"},

    {"Company": "Giant Analytics", 
     "Email": "info@giantanalytics.ai", 
     "Category": "AI & Data Science / Industrial AI Projects", 
     "Source": "https://www.giantanalytics.ai"},

    {"Company": "HashedIn by Deloitte", 
     "Email": "contact@hashedin.com", 
     "Category": "Digital Transformation / Cloud & Data Engineering", 
     "Source": "https://hashedin.com"},

    {"Company": "Fractal Analytics (via MyWorkdayJobs)", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "AI & Analytics Careers / Enterprise AI", 
     "Source": "https://fractal.wd1.myworkdayjobs.com/Careers"},
    
    {"Company": "Dataculous", 
     "Email": "info@dataculous.com", 
     "Category": "Strategic Digital Analytics Consulting / Web & App Analytics", 
     "Source": "https://dataculous.com"},

    {"Company": "Quantiphi", 
     "Email": "info@quantiphi.com", 
     "Category": "AI-First Digital Engineering / Data Science", 
     "Source": "https://quantiphi.com/careers"},

    {"Company": "Boston Institute of Analytics", 
     "Email": "info@bostoninstituteofanalytics.org", 
     "Category": "Data Science Training / Analytics Certification", 
     "Source": "https://bostoninstituteofanalytics.org"},

    {"Company": "Imarticus Learning", 
     "Email": "info@imarticus.com", 
     "Category": "Professional Education / Data Science Training", 
     "Source": "https://www.imarticus.org"},

    {"Company": "TimesPro", 
     "Email": "info@timespro.com", 
     "Category": "Learning / Data Analytics & Business Programs", 
     "Source": "https://www.timespro.com"},

    {"Company": "Indian Institute of Management Mumbai (IIM Mumbai)", 
     "Email": "info@iimmumbai.ac.in", 
     "Category": "Higher Education / Data Science Research", 
     "Source": "https://iimmumbai.ac.in"},

    {"Company": "PW Skills", 
     "Email": "support@pwskills.com", 
     "Category": "Online Training / Data Analytics with AI", 
     "Source": "https://pwskills.com/data-analytics-with-ai-course"},

    {"Company": "Tata Consultancy Services (TCS)", 
     "Email": "corporate.office@tcs.com", 
     "Category": "IT Services / Data Science & Cloud Analytics", 
     "Source": "https://en.wikipedia.org/wiki/List_of_Indian_IT_companies"},

    {"Company": "Agraga", 
     "Email": "info@agraga.com", 
     "Category": "Logistics Data / Supply Chain Analytics", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-scientist-jobs"},

    {"Company": "Envirocare Labs", 
     "Email": "info@envirocare.co.in", 
     "Category": "Environmental Analytics / Testing Lab", 
     "Source": "https://www.envirocare.co.in"},

    {"Company": "Deep HR Services", 
     "Email": "info@deephrservices.com", 
     "Category": "Recruitment / HR Analytics", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-scientist-jobs"},

    {"Company": "Justdial - Data Science Listings", 
     "Email": "support@justdial.com", 
     "Category": "Business Directory / Data Science Service Aggregator", 
     "Source": "https://www.justdial.com"},

    {"Company": "IIM Mumbai - Data Science Lab", 
     "Email": "research@iimmumbai.ac.in", 
     "Category": "Research / Academic Analytics Projects", 
     "Source": "https://iimmumbai.ac.in"},

    {"Company": "Shiksha.com (Data Science Colleges Listing)", 
     "Email": "support@shiksha.com", 
     "Category": "Education Portal / Data Science College Directory", 
     "Source": "https://www.shiksha.com"},
     {"Company": "NeoSOFT Technologies", 
     "Email": "info@neosofttech.com", 
     "Category": "IT Outsourcing / Software Development / Data Science", 
     "Source": "https://www.neosofttech.com"},

    {"Company": "Markytics", 
     "Email": "info@markytics.com", 
     "Category": "Analytics Consulting / Data Science & Insights", 
     "Source": "https://www.markytics.com"},

    {"Company": "Genpact Limited", 
     "Email": "info@genpact.com", 
     "Category": "Business Process / AI & Analytics Services", 
     "Source": "https://www.genpact.com"},

    {"Company": "Tiger Analytics", 
     "Email": "info@tigeranalytics.com", 
     "Category": "AI & Data Analytics Consulting", 
     "Source": "https://www.tigeranalytics.com"},

    {"Company": "Fractal Analytics", 
     "Email": "investorrelations@fractal.ai", 
     "Category": "Enterprise AI / Decision Intelligence", 
     "Source": "https://www.fractal.ai"},

    {"Company": "Tredence", 
     "Email": "info@tredence.com", 
     "Category": "AI and Data Science Consulting", 
     "Source": "https://www.tredence.com"},

    {"Company": "AB InBev (India)", 
     "Email": "india@abinbev.com", 
     "Category": "FMCG / Data-Driven Operations", 
     "Source": "https://www.ab-inbev.com"},

    {"Company": "Expleo Group", 
     "Email": "contact@expleogroup.com", 
     "Category": "Digital Engineering / Data Science & Cybersecurity", 
     "Source": "https://www.expleo.com/global"},

    {"Company": "Bhabha Atomic Research Centre (BARC)", 
     "Email": None, 
     "Category": "Government / Scientific Data Research", 
     "Source": "https://www.barc.gov.in/careers"},

    {"Company": "Devika Staffing Solution", 
     "Email": "hr@devikastaffing.com", 
     "Category": "Recruitment / Data Science Hiring", 
     "Source": "https://www.shine.com/jobs/devika-staffing-solution"},

    {"Company": "Analytics India Magazine (AIM)", 
     "Email": "info@analyticsindiamag.com", 
     "Category": "Media / Analytics & Research", 
     "Source": "https://analyticsindiamag.com"},

    {"Company": "Analytics Insight", 
     "Email": "contact@analyticsinsight.net", 
     "Category": "Media / Analytics & AI Industry Insights", 
     "Source": "https://www.analyticsinsight.net"},

    {"Company": "Justdial - Data Science Listings (Borivali West)", 
     "Email": "support@justdial.com", 
     "Category": "Directory / Local Data Science Services", 
     "Source": "https://www.justdial.com"},

    {"Company": "Unilever India", 
     "Email": None, 
     "Category": "FMCG / Data & Business Analytics", 
     "Source": "https://www.unilever.com"},

    {"Company": "Vskills India", 
     "Email": "info@vskills.in", 
     "Category": "Certifications / Data Science Training", 
     "Source": "https://www.vskills.in"},

    {"Company": "LinkedIn India (Jobs Platform)", 
     "Email": "press@linkedin.com", 
     "Category": "Job Portal / Data Analytics Career Listings", 
     "Source": "https://in.linkedin.com/jobs/data-analytics-jobs-mumbai"},

    {"Company": "Indeed India", 
     "Email": "press@indeed.com", 
     "Category": "Job Portal / Data Science Hiring", 
     "Source": "https://in.indeed.com/q-data-science-l-andheri,-mumbai"},

    {"Company": "Crivva", 
     "Email": "support@crivva.com", 
     "Category": "Tech Platform / Analytics Articles & Company Directory", 
     "Source": "https://crivva.com/Article"},
    {"Company": "NetTech India", 
     "Email": "info@nettechindia.com", 
     "Category": "Education / Data Science & AI Training Institute", 
     "Source": "https://www.nettechindia.com/data-science-course"},

    {"Company": "NMIMS University (Narsee Monjee Institute of Management Studies)", 
     "Email": "enquiry@nmims.edu", 
     "Category": "Higher Education / Data Science, Management & Technology Programs", 
     "Source": "https://www.nmims.edu"},

    {"Company": "EY (Ernst & Young) India", 
     "Email": "contact@in.ey.com", 
     "Category": "Consulting / Data Science & AI Careers", 
     "Source": "https://www.ey.com/en_in/careers"},

    {"Company": "CitiusTech", 
     "Email": "contact@citiustech.com", 
     "Category": "Healthcare Technology / AI & Analytics Solutions", 
     "Source": "https://www.citiustech.com"},

    {"Company": "Bain & Company", 
     "Email": "mumbai.recruiting@bain.com", 
     "Category": "Management Consulting / Analytics & Strategy", 
     "Source": "https://www.bain.com/careers"},

    {"Company": "Zorba Consulting India Pvt. Ltd.", 
     "Email": "info@zorbaconsulting.in", 
     "Category": "Recruitment / AI & Data Science Talent Consulting", 
     "Source": "https://www.naukri.com/head-data-science-jobs"},

    {"Company": "EPAM Systems India", 
     "Email": "info@epam.com", 
     "Category": "Technology Consulting / Data Science & Digital Engineering", 
     "Source": "https://www.epam.com/careers"},

    {"Company": "Microsoft India", 
     "Email": "msindinfo@microsoft.com", 
     "Category": "Technology / Cloud & AI Solutions", 
     "Source": "https://careers.microsoft.com/global/locations/india"},

    {"Company": "Monsoon CreditTech", 
     "Email": "contact@monsooncredit.com", 
     "Category": "FinTech / Machine Learning for Credit Risk", 
     "Source": "https://wellfound.com/role/data-science/mumbai"},

    {"Company": "Infinite Analytics", 
     "Email": "info@infiniteanalytics.com", 
     "Category": "Predictive Analytics / Retail AI Solutions", 
     "Source": "https://wellfound.com/role/data-science/mumbai"},

    {"Company": "Zensciences", 
     "Email": "info@zensciences.com", 
     "Category": "Digital Marketing / Data-Driven B2B Strategy", 
     "Source": "https://www.zensciences.com"},
    {"Company": "LTIMindtree", 
     "Email": "info@ltimindtree.com", 
     "Category": "Technology Consulting / Digital Transformation / Data Solutions", 
     "Source": "https://www.ltimindtree.com"},

    {"Company": "Acuity Knowledge Partners", 
     "Email": "info@acuitykp.com", 
     "Category": "Financial Research / Analytics & Business Intelligence", 
     "Source": "https://www.acuitykp.com"},

    {"Company": "Symonis", 
     "Email": "contact@symonis.com", 
     "Category": "Data Science Startup / Remote Internship Provider", 
     "Source": "https://internshala.com/internship/detail/work-from-home-internship"},

    {"Company": "QSpiders", 
     "Email": "info@qspiders.com", 
     "Category": "IT Training / Data Science & Software Development Courses", 
     "Source": "https://www.qspiders.com"},

    {"Company": "Boston Consulting Group (BCG India)", 
     "Email": "careers.india@bcg.com", 
     "Category": "Management Consulting / Data Science & Strategy", 
     "Source": "https://careers.bcg.com/global/locations/india"},

    {"Company": "Info Edge India Ltd.", 
     "Email": "info@infoedge.in", 
     "Category": "Internet / Recruitment & Data Platform (Naukri, IIMJobs)", 
     "Source": "https://careers.infoedge.com"},

    {"Company": "Tata Consultancy Services (TCS)", 
     "Email": "corporate.office@tcs.com", 
     "Category": "IT Services / Consulting / Data Analytics", 
     "Source": "https://www.tcs.com"},

    {"Company": "Eviden (Atos Group)", 
     "Email": "contact@eviden.com", 
     "Category": "AI & Smart Technology / Sustainable Data Solutions", 
     "Source": "https://www.eviden.com"},

    {"Company": "McKinsey & Company India", 
     "Email": "info_india@mckinsey.com", 
     "Category": "Strategy Consulting / Data Analytics & Research", 
     "Source": "https://www.mckinsey.com/overview"},

    {"Company": "Firstsource Solutions", 
     "Email": "marketing@firstsource.com", 
     "Category": "Business Process Management / Advanced Analytics", 
     "Source": "https://www.firstsource.com"},
    {"Company": "EXL Service", 
     "Email": "info@exlservice.com", 
     "Category": "Digital Transformation / Data & Analytics Consulting", 
     "Source": "https://www.exlservice.com/careers"},

    {"Company": "MSCI", 
     "Email": "careers@msci.com", 
     "Category": "Financial Services / Data Analytics & ESG Research", 
     "Source": "https://careers.msci.com"},

    {"Company": "Deloitte India", 
     "Email": "contactindia@deloitte.com", 
     "Category": "Consulting / AI, Risk, and Data Analytics", 
     "Source": "https://www.deloitte.com/careers"},

    {"Company": "Linedata", 
     "Email": "info@linedata.com", 
     "Category": "Financial Technology / AI & Data Management Solutions", 
     "Source": "https://www.linedata.com"},

    {"Company": "ZS Associates", 
     "Email": "info.india@zs.com", 
     "Category": "Analytics & Consulting / AI-driven Business Solutions", 
     "Source": "https://www.zs.com/careers"},

    {"Company": "Google India", 
     "Email": "press-in@google.com", 
     "Category": "Technology / Data & Machine Learning Engineering", 
     "Source": "https://www.google.com/applications/jobs/results"},

    {"Company": "Genpact", 
     "Email": "info@genpact.com", 
     "Category": "Digital Operations / AI & Analytics Services", 
     "Source": "https://www.genpact.com/careers"},

    {"Company": "NVIDIA India", 
     "Email": "info-india@nvidia.com", 
     "Category": "AI Hardware / Deep Learning & Data Science", 
     "Source": "https://www.nvidia.com/en-in/about-nvidia/careers"},

    {"Company": "HSBC India", 
     "Email": "careers@hsbc.co.in", 
     "Category": "Banking / Analytics & Data Services", 
     "Source": "https://www.hsbc.com/careers/where-we-hire"},

    {"Company": "ICICI Bank", 
     "Email": "careers@icicibank.com", 
     "Category": "Banking / Financial Analytics & Risk Data", 
     "Source": "https://www.icicicareers.com"},
    {"Company": "Ford India", 
     "Email": "careers@ford.com", 
     "Category": "Automotive / Data Science & Digital Innovation", 
     "Source": "https://www.india.ford.com/about-ford/careers"},

    {"Company": "Centre for Development of Advanced Computing (C-DAC)", 
     "Email": "hq@cdac.in", 
     "Category": "Government R&D / Advanced Computing & Data Science", 
     "Source": "https://www.cdac.in"},

    {"Company": "Searce", 
     "Email": "connect@searce.com", 
     "Category": "Cloud Consulting / AI & Data Analytics Partner (Google Cloud)", 
     "Source": "https://cloud.google.com/find-a-partner"},

    {"Company": "Ness Digital Engineering", 
     "Email": "info@ness.com", 
     "Category": "Digital Engineering / Data Platforms & MLOps", 
     "Source": "https://www.ness.com"},

    {"Company": "Oracle India", 
     "Email": "inpress_ww@oracle.com", 
     "Category": "Cloud & Database Solutions / Data Analytics & AI Careers", 
     "Source": "https://www.oracle.com/careers"},

    {"Company": "Goldman Sachs India", 
     "Email": "careers-india@gs.com", 
     "Category": "Financial Services / Quantitative & Analytics Careers", 
     "Source": "https://www.goldmansachs.com/worldwide/careers"},

    {"Company": "TalentSprint", 
     "Email": "info@talentsprint.com", 
     "Category": "Deep Tech Education / Applied Data Science Training", 
     "Source": "https://www.talentsprint.com"},

    {"Company": "KPMG India", 
     "Email": "in-fmcareers@kpmg.com", 
     "Category": "Professional Services / AI, Data & Risk Consulting", 
     "Source": "https://kpmg.com/careers"},

    {"Company": "Capgemini India", 
     "Email": "contact.in@capgemini.com", 
     "Category": "IT Consulting / Cloud, Data & AI Transformation", 
     "Source": "https://www.capgemini.com/careers"},

    {"Company": "Infosys", 
     "Email": "infosys@infosys.com", 
     "Category": "Digital Services / Consulting & Data Transformation", 
     "Source": "https://www.infosys.com"},
    {"Company": "Motilal Oswal Group", 
     "Email": "careers@motilaloswal.com", 
     "Category": "BFSI / Data Science & Financial Analytics", 
     "Source": "https://www.motilaloswalgroup.com/Careersweb/CurrentOpenings"},

    {"Company": "Optum India (UnitedHealth Group)", 
     "Email": "contact@optum.in", 
     "Category": "Healthcare Technology / Data & AI Solutions", 
     "Source": "https://www.optum.in/about/careers"},

    {"Company": "Nagarro", 
     "Email": "info@nagarro.com", 
     "Category": "Digital Engineering / AI & Data Science Consulting", 
     "Source": "https://www.nagarro.com/careers"},

    {"Company": "Infinite Computer Solutions", 
     "Email": "contact@infinite.com", 
     "Category": "Global IT Services / Distributed Data Analytics", 
     "Source": "https://www.infinite.com"},

    {"Company": "Infogain", 
     "Email": "info@infogain.com", 
     "Category": "Digital Transformation / Analytics & Cloud Solutions", 
     "Source": "https://www.infogain.com/careers"},

    {"Company": "Merck Group India (Merck KGaA)", 
     "Email": "info.india@merckgroup.com", 
     "Category": "Life Sciences / Technology & Data Analytics", 
     "Source": "https://www.merckgroup.com/in-en"},

    {"Company": "Salesforce India", 
     "Email": "info@salesforce.com", 
     "Category": "Cloud CRM / Data & AI Integration Solutions", 
     "Source": "https://www.salesforce.com/careers/locations/india"},

    {"Company": "LinkedIn India (Navi Mumbai Jobs)", 
     "Email": "press@linkedin.com", 
     "Category": "Job Platform / Data Science & Analytics Opportunities", 
     "Source": "https://in.linkedin.com/jobs/data-science-jobs-navi-mumbai"},

    {"Company": "Nokia India", 
     "Email": "careers.india@nokia.com", 
     "Category": "Telecom / Data Science & Network Analytics", 
     "Source": "https://www.nokia.com/careers"},

    {"Company": "Intellipaat", 
     "Email": "sales@intellipaat.com", 
     "Category": "Education / Data Science & AI Training", 
     "Source": "https://www.youtube.com/@Intellipaat"},
    {"Company": "Birla Institute of Technology and Science (BITS Pilani)", 
     "Email": "info@bits-pilani.ac.in", 
     "Category": "Higher Education / Data Science & Engineering Programs", 
     "Source": "https://www.bits-pilani.ac.in"},

    {"Company": "Tredence", 
     "Email": "info@tredence.com", 
     "Category": "AI and Data Analytics Consulting / Data-Driven Solutions", 
     "Source": "https://www.tredence.com/blog/top-100-companies-for-data-scientists-in-india"},

    {"Company": "WNS Global Services", 
     "Email": "marketing@wns.com", 
     "Category": "Business Process Management / Analytics & Digital Transformation", 
     "Source": "https://www.wns.com"},

    {"Company": "Innovatics", 
     "Email": "contact@teaminnovatics.com", 
     "Category": "AI & Data Analytics Consulting / Automation Solutions", 
     "Source": "https://teaminnovatics.com"},

    {"Company": "Coding Ninjas", 
     "Email": "support@codingninjas.com", 
     "Category": "EdTech / Data Science & Machine Learning Training", 
     "Source": "https://www.codingninjas.com"},

    {"Company": "Peroptyx", 
     "Email": "info@peroptyx.com", 
     "Category": "AI Data Annotation / Model Evaluation Solutions", 
     "Source": "https://www.peroptyx.com"},

    {"Company": "Invesco India", 
     "Email": "careers.india@invesco.com", 
     "Category": "Investment Management / Big Data & Quantitative Analytics", 
     "Source": "https://careers.invesco.com/india"},

    {"Company": "Colab Cloud Platforms Ltd.", 
     "Email": "info@colabcloud.com", 
     "Category": "Cloud Data Solutions / AI Infrastructure", 
     "Source": "https://www.glassdoor.com/Job/mumbai-data-scientist-jobs"},

    {"Company": "LRN Corporation", 
     "Email": "info@lrn.com", 
     "Category": "Corporate Compliance / Analytics & Data Strategy", 
     "Source": "https://www.lrn.com"},

    {"Company": "BusinessFirms India", 
     "Email": "support@businessfirms.co", 
     "Category": "Business Directory / Data Science Company Listings", 
     "Source": "https://businessfirms.co/data-science-companies-in-मुंबई"},
    {"Company": "Justdial - Data Science Services (Lower Parel, Mumbai)", 
     "Email": "support@justdial.com", 
     "Category": "Business Directory / Data Science Services Aggregator", 
     "Source": "https://www.justdial.com"},

    {"Company": "HTC Global Services (HTC Inc.)", 
     "Email": "info@htcinc.com", 
     "Category": "Technology Consulting / Enterprise AI & Data Modernization", 
     "Source": "https://www.htcinc.com"},

    {"Company": "OTSI Global", 
     "Email": "info@otsi-global.com", 
     "Category": "IT Solutions / AI, Cloud & Digital Transformation", 
     "Source": "https://otsi-global.com"},

    {"Company": "Allcargo Logistics", 
     "Email": "careers@allcargologistics.com", 
     "Category": "Logistics / Data Science & AI Engineering", 
     "Source": "https://in.indeed.com/q-data-analyst-,-data-scientist-l-mumbai"},

    {"Company": "Datamatics Global Services", 
     "Email": "marketing@datamatics.com", 
     "Category": "Digital Technologies / AI & Data Analytics", 
     "Source": "https://www.datamatics.com"},

    {"Company": "Cyient", 
     "Email": "info@cyient.com", 
     "Category": "Engineering / AI, Analytics & Cloud Solutions", 
     "Source": "https://www.cyient.com"},

    {"Company": "Xoriant", 
     "Email": "info@xoriant.com", 
     "Category": "Digital Engineering / Data Analytics Modernization", 
     "Source": "https://www.xoriant.com/about-xoriant"},

    {"Company": "Eli Lilly and Company (Lilly India)", 
     "Email": "info@lilly.com", 
     "Category": "Pharmaceuticals / Data Science & Clinical Analytics", 
     "Source": "https://www.lilly.com/careers"},

    {"Company": "eClerx Services Ltd.", 
     "Email": "info@eclerx.com", 
     "Category": "Business Process / AI & Data Transformation", 
     "Source": "https://www.eclerx.com"},

    {"Company": "McKinsey & Company India", 
     "Email": "info_india@mckinsey.com", 
     "Category": "Consulting / Advanced Analytics for Strategy & Finance", 
     "Source": "https://www.mckinsey.com/careers/search-jobs"},
    {"Company": "NVIDIA India", 
     "Email": "info-india@nvidia.com", 
     "Category": "Artificial Intelligence / Data Science Computing Solutions", 
     "Source": "https://www.nvidia.com/en-in"},

    {"Company": "Accenture India", 
     "Email": "careers@accenture.com", 
     "Category": "Consulting / AI, Data Science & Cloud Transformation", 
     "Source": "https://www.accenture.com/in-en/careers/jobsearch"},

    {"Company": "LinkedIn India", 
     "Email": "press@linkedin.com", 
     "Category": "Job Platform / Data Science & Analytics Opportunities", 
     "Source": "https://in.linkedin.com/jobs/data-science-jobs-mumbai"},

    {"Company": "Boston Consulting Group (BCG India)", 
     "Email": "careers.india@bcg.com", 
     "Category": "Consulting / Data Science & Analytics Practice (BCG X)", 
     "Source": "https://in.indeed.com/q-data-science-jobs"},

    {"Company": "Justdial - Data Science Services (Bandra West, Mumbai)", 
     "Email": "support@justdial.com", 
     "Category": "Local Data Science & ML Services Listing", 
     "Source": "https://www.justdial.com"},

    {"Company": "DBS Bank India", 
     "Email": "careersindia@dbs.com", 
     "Category": "Banking / Data Science & AI-Driven Financial Analytics", 
     "Source": "https://www.glassdoor.com/Job/mumbai-lead-data-s"},

    {"Company": "HERE Technologies India", 
     "Email": "info.india@here.com", 
     "Category": "Geospatial Technology / Data Science & Mapping AI", 
     "Source": "https://www.naukri.com/senior-data-scientist-jobs"},

    {"Company": "LRN Corporation", 
     "Email": "info@lrn.com", 
     "Category": "Corporate Compliance / Data Strategy & Analytics", 
     "Source": "https://www.naukri.com/senior-data-scientist-jobs"},

    {"Company": "McKinsey & Company India", 
     "Email": "info_india@mckinsey.com", 
     "Category": "Consulting / Strategy & Advanced Analytics Careers", 
     "Source": "https://www.mckinsey.com/careers-in-india"},

    {"Company": "Procter & Gamble India", 
     "Email": "careers.india@pg.com", 
     "Category": "Consumer Goods / Data Science & Product Analytics", 
     "Source": "https://in.linkedin.com/jobs/data-scientist-analytics-jobs"},
    {"Company": "Arnavix HR Services", 
     "Email": "info@arnavixhr.com", 
     "Category": "Recruitment / Data Science & Analytics Placement Services", 
     "Source": "https://www.justdial.com"},

    {"Company": "Cloud 9 Manpower Services", 
     "Email": "contact@cloud9manpower.com", 
     "Category": "Recruitment / Data Science Staffing for Employers", 
     "Source": "https://www.justdial.com"},

    {"Company": "Ujval Career Centre & Job Consultancy", 
     "Email": "info@ujvalcareercentre.com", 
     "Category": "Recruitment / HR & Data Science Job Consultancy", 
     "Source": "https://www.justdial.com"},

    {"Company": "Agraga", 
     "Email": "careers@agraga.com", 
     "Category": "Supply Chain Tech / Assistant Data Analyst Roles", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-analy"},

    {"Company": "Open Secret", 
     "Email": "careers@opensecret.in", 
     "Category": "FMCG / Data Analytics Hiring in Mumbai", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-analy"},

    {"Company": "Quantiphi Analytics", 
     "Email": "info@quantiphi.com", 
     "Category": "AI & Machine Learning / Data Science Solutions", 
     "Source": "https://www.techvts.com/leading-companies-and-startups-in-mumbai"},

    {"Company": "LevelShift Analytics", 
     "Email": "info@levelshift.io", 
     "Category": "Analytics Consulting / Data Science Services", 
     "Source": "https://www.naukri.com/data-science-and-analytics-companies"},

    {"Company": "IndiaMART InterMESH Ltd.", 
     "Email": "support@indiamart.com", 
     "Category": "E-Commerce / Data Analytics & Market Intelligence", 
     "Source": "https://www.naukri.com/data-science-and-analytics-companies"},

    {"Company": "IQVIA India", 
     "Email": "contact@iqvia.com", 
     "Category": "Healthcare Data Analytics / AI & Clinical Research", 
     "Source": "https://www.naukri.com/data-analyst-jobs"},

    {"Company": "DIGI-LATERAL Solutions", 
     "Email": "info@digilateral.in", 
     "Category": "Digital Solutions / Data Science Internships", 
     "Source": "https://in.indeed.com/q-data-science-internship-l-mumbai"},
     {"Company": "Visa Consulting & Analytics (India & South Asia)", 
     "Email": "careers@visa.com", 
     "Category": "Financial Technology / Director, Data Science & Analytics Roles", 
     "Source": "https://in.linkedin.com/jobs/senior-data-scientist-jobs-mumbai"},

    {"Company": "Allcargo Logistics", 
     "Email": "careers@allcargologistics.com", 
     "Category": "Logistics / AI & Data Science for Supply Chain", 
     "Source": "https://www.glassdoor.com/job/mumbai-data-scienti"},

    {"Company": "LRN Corporation", 
     "Email": "info@lrn.com", 
     "Category": "Corporate Ethics & Compliance / Data Analytics Hiring", 
     "Source": "https://www.glassdoor.com/job/mumbai-data-scienti"},

    {"Company": "Skitch Technologies Pvt. Ltd.", 
     "Email": "info@skitch.in", 
     "Category": "AI & Machine Learning / Data Science Hiring", 
     "Source": "https://www.glassdoor.com/job/mumbai-data-scienti"},

    {"Company": "GEP Worldwide", 
     "Email": "careers@gep.com", 
     "Category": "Procurement & Analytics / Data & Business Intelligence", 
     "Source": "https://www.naukri.com/data-analytics-jobs"},

    {"Company": "Suzva Software Technologies", 
     "Email": "info@suzva.com", 
     "Category": "Software & Data Engineering / Data Analytics Roles", 
     "Source": "https://www.naukri.com/data-analytics-jobs"},

    {"Company": "Showstoper Technologies & Media Pvt. Ltd.", 
     "Email": "contact@showstopermedia.com", 
     "Category": "Media Tech / Data Analytics Services", 
     "Source": "https://www.justdial.com"},

    {"Company": "Tekolutions", 
     "Email": "info@tekolutions.com", 
     "Category": "Tech Consulting / Data Science & Cloud Analytics", 
     "Source": "https://www.justdial.com"},

    {"Company": "General Mills India", 
     "Email": "careers.india@genmills.com", 
     "Category": "Consumer Goods / Data Science & Analytics Hiring", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-analy"},

    {"Company": "Trafigura Global", 
     "Email": "info@trafigura.com", 
     "Category": "Commodities Trading / Data Analytics & Risk Management", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-analy"},
    {"Company": "LinkedIn India", 
     "Email": "press@linkedin.com", 
     "Category": "Job Platform / Data Science & Analytics Roles Aggregator", 
     "Source": "https://in.linkedin.com/jobs/data-science-jobs-mumbai"},

    {"Company": "Caratlane", 
     "Email": "careers@caratlane.com", 
     "Category": "E-commerce / Data Science & Customer Insights", 
     "Source": "https://www.naukri.com/junior-data-scientist-jobs"},

    {"Company": "V4C Info Systems", 
     "Email": "info@v4cinfosystems.com", 
     "Category": "IT Solutions / Data Engineering & Analytics Services", 
     "Source": "https://www.naukri.com/junior-data-scientist-jobs"},

    {"Company": "IQVIA India", 
     "Email": "contact@iqvia.com", 
     "Category": "Healthcare Data / Analytics & Clinical Research", 
     "Source": "https://www.naukri.com/data-analyst-jobs"},

    {"Company": "Isprava Group", 
     "Email": "careers@isprava.com", 
     "Category": "Luxury Real Estate / Data Analytics & Insights", 
     "Source": "https://www.naukri.com/data-analyst-jobs"},

    {"Company": "GEP Worldwide", 
     "Email": "careers@gep.com", 
     "Category": "Procurement & Analytics / Data & AI Consulting", 
     "Source": "https://www.naukri.com/job-listings-project-manager-data-and-analytics"},

    {"Company": "Unnamed IT Company (Databricks Role)", 
     "Email": "info@databricks-partner.com", 
     "Category": "IT Services / Data Engineering & AI with Databricks", 
     "Source": "https://www.naukri.com/job-listings-data-engineer-sr-data-engineer-databricks"},

    {"Company": "Equity Data Science (EDS)", 
     "Email": "info@equitydatascience.com", 
     "Category": "Investment Analytics / Quant & Market Data Research", 
     "Source": "https://in.linkedin.com/jobs/equity-data-science-jobs-mumbai"},

    {"Company": "General Mills India", 
     "Email": "careers.india@genmills.com", 
     "Category": "FMCG / Analytics & Data Science Hiring", 
     "Source": "https://www.glassdoor.co.in/job/mumbai-data-analy"},

    {"Company": "GEP Worldwide (Project Manager Role - Navi Mumbai)", 
     "Email": "recruitment@gep.com", 
     "Category": "Consulting / Project Management in Data & Analytics", 
     "Source": "https://www.naukri.com/job-listings-project-manager-data-and-analytics"},
    {"Company": "ICICI Lombard General Insurance Co. Ltd.", 
     "Email": "careers@icicilombard.com", 
     "Category": "Insurance / Data Analytics & Risk Modeling", 
     "Source": "https://in.linkedin.com/jobs/analyst-data-scientist-jobs-mumbai"},

    {"Company": "Unnamed IT Company (Databricks Role)", 
     "Email": "info@databricks-partner.com", 
     "Category": "IT & Data Science Services / Databricks Engineering", 
     "Source": "https://www.naukri.com/job-listings-data-engineer-sr-data-engineer-databricks"},

    {"Company": "USWA WEA Technologies", 
     "Email": "info@uswawea.com", 
     "Category": "Software Development / AI & Python Backend Engineering", 
     "Source": "https://in.linkedin.com/jobs/data-scientist-work-from-home-jobs-mumbai"},

    {"Company": "Capgemini Engineering", 
     "Email": "contact.in@capgemini.com", 
     "Category": "Engineering Services / AI, ML & Data Science Hiring", 
     "Source": "https://in.linkedin.com/jobs/lead-data-science-jobs-mumbai"},

    {"Company": "Visa Consulting & Analytics (India & South Asia)", 
     "Email": "careers@visa.com", 
     "Category": "Financial Technology / Data Science & Business Analytics", 
     "Source": "https://in.linkedin.com/jobs/data-science-manager-jobs-mumbai"},

    {"Company": "SAP India (HANA Analytics Cloud)", 
     "Email": "info@sap.com", 
     "Category": "Enterprise Cloud / SAP SAC & Analytics Cloud Consulting", 
     "Source": "https://www.naukri.com/hana-analytics-jobs"},

    {"Company": "LinkedIn India", 
     "Email": "press@linkedin.com", 
     "Category": "Job Platform / Data Science & Analytics Roles Aggregator", 
     "Source": "https://in.linkedin.com/jobs/data-scientist-mumbai-jobs"},

    {"Company": "Capgemini Engineering (GEN AI Division)", 
     "Email": "info@capgemini.com", 
     "Category": "Consulting / AI, GEN AI, Python ML Engineering", 
     "Source": "https://in.linkedin.com/jobs/lead-data-science-jobs-mumbai"},

    {"Company": "Equity Data Science (EDS)", 
     "Email": "info@equitydatascience.com", 
     "Category": "Investment Analytics / Quantitative Research & Data Science", 
     "Source": "https://in.linkedin.com/jobs/equity-data-science-jobs-mumbai"},

    {"Company": "GEP Worldwide", 
     "Email": "careers@gep.com", 
     "Category": "Procurement & Analytics / Project Management in Data Science", 
     "Source": "https://www.naukri.com/job-listings-project-manager-data-and-analytics"},
    
]

# %%
df = pd.DataFrame(data)
df
# Out:
#                                      Company  \
# 0    Quantiphi Analytics Solutions Pvt. Ltd.
# 1             Data Science Wizards Pvt. Ltd.
# 2           Credence Analytics (I) Pvt. Ltd.
# 3                    Decimal Point Analytics
# 4                         Persistent Systems
# ..                                       ...
# 297         SAP India (HANA Analytics Cloud)
# 298                           LinkedIn India
# 299  Capgemini Engineering (GEN AI Division)
# 300                Equity Data Science (EDS)
# 301                            GEP Worldwide
#
#                                 Email  \
# 0                  info@quantiphi.com
# 1       contact@datasciencewizards.ai
# 2    anitakumar@credenceanalytics.com
# 3      info@decimalpointanalytics.com
# 4            investors@persistent.com
# ..                                ...
# 297                      info@sap.com
# 298                press@linkedin.com
# 299                info@capgemini.com
# ...

# %%
df.to_csv("mumbai_data_science_companies.csv", index=False)
